# %% [markdown]
# <img src="http://imgur.com/1ZcRyrc.png" style="float: left; margin: 20px; height: 55px">
#
# ## Lab: Cleaning Rock Song Data
#
# _Authors: Dave Yerrington (SF)_
#
# ---

# %%
import pandas as pd
import numpy as np 
import seaborn as sns

# %matplotlib inline

# %% [markdown]
# ### 1. Load `rock.csv` and do an initial examination of its data columns.

# %%
rockfile = "datasets/rock.csv"

# %%
# Load the data.
data = pd.read_csv(rockfile)

data.head(20)
# Out:
#                                    Song         Artist  Release Year  \
# 0                       Hold On Loosely    .38 Special          1981
# 1                     Art For Arts Sake           10cc          1975
# 2                            Kryptonite   3 Doors Down          2000
# 3                                 Loser   3 Doors Down          2000
# 4                         When I'm Gone   3 Doors Down          2002
# 5                            What's Up?  4 Non Blondes          1992
# 6                            Take On Me           a-ha          1985
# 7                 Baby, Please Don't Go          AC/DC           NaN
# 8                         Back In Black          AC/DC          1980
# 9                               Big Gun          AC/DC          1993
# 10               CAN'T STOP ROCK'N'ROLL          AC/DC           NaN
# 11              For Those About To Rock          AC/DC          1981
# 12                     Girls Got Rhythm          AC/DC           NaN
# 13           It's A Long Way To The Top          AC/DC          1975
# 14                            Jailbreak          AC/DC          1984
# 15                    Let There Be Rock          AC/DC          1977
# 16                            Live Wire          AC/DC           NaN
# 17                           Moneytalks          AC/DC           NaN
# 18  Rock and Roll Ain't Noise Pollution          AC/DC          1980
# 19                      Shoot To Thrill          AC/DC           NaN
#
#                                         Combined  First?  Year?  PlayCount  \
# 0                 Hold On Loosely by .38 Special       1      1         85
# 1                      Art For Arts Sake by 10cc       1      1          1
# 2                     Kryptonite by 3 Doors Down       1      1         13
# 3                          Loser by 3 Doors Down       1      1          1
# 4                  When I'm Gone by 3 Doors Down       1      1          6
# 5                    What's Up? by 4 Non Blondes       1      1          3
# 6                             Take On Me by a-ha       1      1          1
# 7                 Baby, Please Don't Go by AC/DC       1      0          1
# 8                         Back In Black by AC/DC       1      1         97
# 9                               Big Gun by AC/DC       1      1          6
# 10               CAN'T STOP ROCK'N'ROLL by AC/DC       1      0          5
# 11              For Those About To Rock by AC/DC       1      1         46
# 12                     Girls Got Rhythm by AC/DC       1      0         24
# 13           It's A Long Way To The Top by AC/DC       1      1         39
# 14                            Jailbreak by AC/DC       1      1          1
# 15                    Let There Be Rock by AC/DC       1      1          3
# 16                            Live Wire by AC/DC       1      0          2
# 17                           Moneytalks by AC/DC       1      0         20
# 18  Rock and Roll Ain't Noise Pollution by AC/DC       1      1         21
# 19                      Shoot To Thrill by AC/DC       1      0         45
#
#     F*G
# 0    85
# 1     1
# 2    13
# 3     1
# 4     6
# 5     3
# 6     1
# 7     0
# 8    97
# 9     6
# 10    0
# 11   46
# 12    0
# 13   39
# 14    1
# 15    3
# 16    0
# 17    0
# 18   21
# 19    0

# %%
# Look at the information regarding its columns.
data.keys()
data.isnull().sum()
# Out:
# Song               0
#  Artist            0
#  Release Year    533
# Combined           0
# First?             0
# Year?              0
# PlayCount          0
# F*G                0
# dtype: int64

# %% [markdown]
# ### 2.  Clean up the column names.
#
# Let's clean up the column names. There are two ways we can accomplish this:
#
# #### 2.A Change the column names when you import the data using `pd.read_csv()`.
#
# Notice that, when passing `names=[..A LIST OF STRING..]` with a number of columns that matches the number of strings in the passed list, you replace the column names.
#
# NOTE: When you create custom column names, the first row of the `.csv` already represents a header. It is important to tell `pandas` to skip that row. The `skiprows=1` keyword argument to `read_csv()` will tell `pandas` to skip the first row.

# %%
# Change the column names when loading the '.csv':
columnNames =['SongName','Artist','Release Year','Combined',"First?",'year?','Playcount','fg']
df = pd.read_csv(rockfile, names=columnNames, skiprows=1)
df.head()
# Out:
#             SongName        Artist Release Year  \
# 0    Hold On Loosely   .38 Special         1981
# 1  Art For Arts Sake          10cc         1975
# 2         Kryptonite  3 Doors Down         2000
# 3              Loser  3 Doors Down         2000
# 4      When I'm Gone  3 Doors Down         2002
#
#                          Combined  First?  year?  Playcount  fg
# 0  Hold On Loosely by .38 Special       1      1         85  85
# 1       Art For Arts Sake by 10cc       1      1          1   1
# 2      Kryptonite by 3 Doors Down       1      1         13  13
# 3           Loser by 3 Doors Down       1      1          1   1
# 4   When I'm Gone by 3 Doors Down       1      1          6   6

# %% [markdown]
# #### 2.B Change column names using the `.rename()` function.
#
# The `.rename()` function takes an argument, `columns=name_dict`, in which `name_dict` is a dictionary containing the original column names as keys and the new column names as values.

# %%
# Change the column names using the `.rename()` function.
df= pd.read_csv(rockfile)

rename_columns = {
        # Original column: [renamed column]
    'Song Clean':    'song', 
    'ARTIST CLEAN':  'artist', 
    'Release Year':  'release', 
    'COMBINED':      'song_artist', 
    'First?':        'first', 
    'Year?':         'year', 
    'PlayCount':     'playcount', 
    'F*G':           'fg'
}
df.head()
df.rename( columns = rename_columns, inplace = 1)
df.head()
# Out:
#                 Song        Artist  Release Year  \
# 0    Hold On Loosely   .38 Special          1981
# 1  Art For Arts Sake          10cc          1975
# 2         Kryptonite  3 Doors Down          2000
# 3              Loser  3 Doors Down          2000
# 4      When I'm Gone  3 Doors Down          2002
#
#                          Combined  first  year  playcount  fg
# 0  Hold On Loosely by .38 Special      1     1         85  85
# 1       Art For Arts Sake by 10cc      1     1          1   1
# 2      Kryptonite by 3 Doors Down      1     1         13  13
# 3           Loser by 3 Doors Down      1     1          1   1
# 4   When I'm Gone by 3 Doors Down      1     1          6   6

# %% [markdown]
# #### 2.C Reassigning the `.columns` attribute of a DataFrame.
#
# You can also just reassign the `.columns` attribute to a list of strings containing the new column names.
#
# The only caveat with reassigning `.columns` is that you have to reassign all of the column names at once. You can't partially replace a value by working on `.columns` directly. You have to reassign `.columns` with a list of equal length.

# %%
# Replace the column names by reassigning the `.columns` attribute.
df= pd.read_csv(rockfile)

rename_columns = {
        # Original column: [renamed column]
    'Song Clean':    'song', 
    'ARTIST CLEAN':  'artist', 
    'Release Year':  'release', 
    'COMBINED':      'song_artist', 
    '??First?':        'first', 
    '??Year?':         'year', 
    'PlayCount':     'playcount', 
    'F*G':           'fg'
}
df.columns = rename_columns
df.head(12)
# Out:
#                  Song Clean   ARTIST CLEAN Release Year  \
# 0           Hold On Loosely    .38 Special         1981
# 1         Art For Arts Sake           10cc         1975
# 2                Kryptonite   3 Doors Down         2000
# 3                     Loser   3 Doors Down         2000
# 4             When I'm Gone   3 Doors Down         2002
# 5                What's Up?  4 Non Blondes         1992
# 6                Take On Me           a-ha         1985
# 7     Baby, Please Don't Go          AC/DC          NaN
# 8             Back In Black          AC/DC         1980
# 9                   Big Gun          AC/DC         1993
# 10   CAN'T STOP ROCK'N'ROLL          AC/DC          NaN
# 11  For Those About To Rock          AC/DC         1981
#
#                             COMBINED  ??First?  ??Year?  PlayCount  F*G
# 0     Hold On Loosely by .38 Special         1        1         85   85
# 1          Art For Arts Sake by 10cc         1        1          1    1
# 2         Kryptonite by 3 Doors Down         1        1         13   13
# 3              Loser by 3 Doors Down         1        1          1    1
# 4      When I'm Gone by 3 Doors Down         1        1          6    6
# 5        What's Up? by 4 Non Blondes         1        1          3    3
# 6                 Take On Me by a-ha         1        1          1    1
# 7     Baby, Please Don't Go by AC/DC         1        0          1    0
# 8             Back In Black by AC/DC         1        1         97   97
# 9                   Big Gun by AC/DC         1        1          6    6
# 10   CAN'T STOP ROCK'N'ROLL by AC/DC         1        0          5    0
# 11  For Those About To Rock by AC/DC         1        1         46   46

# %% [markdown]
# ### 3. Subsetting data where null values exist.
#
# We have mixed `str` and `NaN` values in the `release` column. `NaN` stands for "not a number" and is the way `pandas` handles "nulls" or nonexistent data. We can use the `.isnull()` method of a Series to find null values.
#
# Print the header of the data subset to where the `release` column is null values.

# %%
# Show records where df['release'] is null
print(df.isnull().sum())

nullReleasValue = df['Release Year'].isnull()
df[nullReleasValue].head(10)

#df.info()
# Out:
# Song Clean        0
# ARTIST CLEAN      0
# Release Year    533
# COMBINED          0
# ??First?          0
# ??Year?           0
# PlayCount         0
# F*G               0
# dtype: int64
#                         Song Clean ARTIST CLEAN Release Year  \
# 7            Baby, Please Don't Go        AC/DC          NaN
# 10          CAN'T STOP ROCK'N'ROLL        AC/DC          NaN
# 12                Girls Got Rhythm        AC/DC          NaN
# 16                       Live Wire        AC/DC          NaN
# 17                      Moneytalks        AC/DC          NaN
# 19                 Shoot To Thrill        AC/DC          NaN
# 21                        Sin City        AC/DC          NaN
# 24  What Do You Do For Money Honey        AC/DC          NaN
# 30           Baby, Please Don't Go    Aerosmith          NaN
# 33                   Come Together    Aerosmith          NaN
#
#                                    COMBINED  ??First?  ??Year?  PlayCount  F*G
# 7            Baby, Please Don't Go by AC/DC         1        0          1    0
# 10          CAN'T STOP ROCK'N'ROLL by AC/DC         1        0          5    0
# 12                Girls Got Rhythm by AC/DC         1        0         24    0
# 16                       Live Wire by AC/DC         1        0          2    0
# 17                      Moneytalks by AC/DC         1        0         20    0
# 19                 Shoot To Thrill by AC/DC         1        0         45    0
# 21                        Sin City by AC/DC         1        0          1    0
# 24  What Do You Do For Money Honey by AC/DC         1        0          2    0
# 30       Baby, Please Don't Go by Aerosmith         1        0          1    0
# 33               Come Together by Aerosmith         1        0         65    0

# %% [markdown]
# ### 4. Update slices of your DataFrame based on mask selection/slices.
#
# In many scenarios, we want to upate values in our DataFrame according to criteria. Let's say we wanted to set all of the null values in `release` to 0.
#
# With newer versions of `pandas`, in order to manipulate data in the original DataFrame, we have to use `.loc` while performing reassignment using a mask and an index.
#
# For example, the following won't always work:
# ```python
# df[row_mask]['column_name'] = new_value
# ```
#
# The best way to accomplish the same task is:
# ```python
# df.loc[row_mask, 'column_name'] = new_value
# ```
#
# For multiple column assignment, you would use:
# ```python
# df.loc[row_mask, ['col_1', 'col_2', 'col_3']] = new_value
# ```
#
# #### 4.A Let's try it out. Make all of the null values in `release` 0.

# %%
# Replace release nulls with 0

nullReleasValue = df['Release Year'].isnull()
df[nullReleasValue].head(10)

df.loc[nullReleasValue, 'Release Year'] = 0

df.head(15)
df[df['Release Year'] == 0]
# Out:
#                           Song Clean              ARTIST CLEAN  Release Year  \
# 7              Baby, Please Don't Go                     AC/DC           0.0
# 10            CAN'T STOP ROCK'N'ROLL                     AC/DC           0.0
# 12                  Girls Got Rhythm                     AC/DC           0.0
# 16                         Live Wire                     AC/DC           0.0
# 17                        Moneytalks                     AC/DC           0.0
# 19                   Shoot To Thrill                     AC/DC           0.0
# 21                          Sin City                     AC/DC           0.0
# 24    What Do You Do For Money Honey                     AC/DC           0.0
# 30             Baby, Please Don't Go                 Aerosmith           0.0
# 33                     Come Together                 Aerosmith           0.0
# 41                  Kings and Queens                 Aerosmith           0.0
# 47                    One Way Street                 Aerosmith           0.0
# 53                    The Other Side                 Aerosmith           0.0
# 58                 You See Me Crying                 Aerosmith           0.0
# 65                     House Of Fire              Alice Cooper           0.0
# 85                       One Way Out      Allman Brothers Band           0.0
# 87                        Southbound      Allman Brothers Band           0.0
# 94                    Immigrant Song                Ann Wilson           0.0
# 95                            Roller                April Wine           0.0
# 97           Coming into Los Angeles              Arlo Guthrie           0.0
# 98                           Wayside             Artful Dodger           0.0
# 102                           Spooky    Atlanta Rhythm Section           0.0
# 106         Roll On Down The Highway  Bachman-Turner Overdrive           0.0
# 112                   Gone Gone Gone               Bad Company           0.0
# 113                        Movin' On               Bad Company           0.0
# 114                   Ready For Love               Bad Company           0.0
# 115            Rock 'n' Roll Fantasy               Bad Company           0.0
# 116                      Rock Steady               Bad Company           0.0
# 117                Run With The Pack               Bad Company           0.0
# 120            Silver, Blue And Gold               Bad Company           0.0
# ...                              ...                       ...           ...
# 2009        Somebody Get Me A Doctor                 Van Halen           0.0
# 2011                       Top Jimmy                 Van Halen           0.0
# 2012                Top of the World                 Van Halen           0.0
# 2018                And It Stoned Me              Van Morrison           0.0
# 2019                      BLUE MONEY              Van Morrison           0.0
# 2023                          Gloria              Van Morrison           0.0
# 2025              Jackie Wilson Said              Van Morrison           0.0
# 2029          Edge of a Broken Heart                     Vixen           0.0
# 2034               Uncle Tom's Cabin                   Warrant           0.0
# 2038          Street Corner Serenade                Wet Willie           0.0
# 2039                            Wait                White Lion           0.0
# 2038               Street Corner Serenade by Wet Willie         1        0
# 2039                                 Wait by White Lion         1        0
# 2043                        Slow An' Easy by Whitesnake         1        0
# 2044                   Still of the Night by Whitesnake         1        0
# 2045                            Who Are You? by Why Not         1        0
# 2047                            Night Moves by Wildlife         1        0
# 2048                      We've Got Tonight by Wildlife         1        0
# 2049                         Can't Get Enough by Winger         1        0
# 2050                  Headed For A Heartbreak by Winger         1        0
# 2051                                Seventeen by Winger         1        0
# 2053                            Summertime Girls by Y&T         1        0
# 2062                           Wonderous Stories by Yes         1        0
# 2064                     Tell Me What You Want by Zebra         1        0
# 2065                     Who's Behind The Door by Zebra         1        0
# 2067                A Fool for Your Stockings by ZZ Top         1        0
# 2073                              I Thank You by ZZ Top         1        0
# 2074                  I'm Bad, I'm Nationwide by ZZ Top         1        0
# 2076                            Just Got Paid by ZZ Top         1        0
# 2079                 My Head's In Mississippi by ZZ Top         1        0
# 2080                       Party On The Patio by ZZ Top         1        0
# 2083                  She Loves My Automobile by ZZ Top         1        0
#
#       PlayCount  F*G
# 7             1    0
# 10            5    0
# 12           24    0
# 16            2    0
# 17           20    0
# 19           45    0
# 21            1    0
# 24            2    0
# 30            1    0
# 33           65    0
# 41            1    0
# 47            1    0
# 53           11    0
# 58            1    0
# 65            1    0
# 85            3    0
# 87            2    0
# 94            2    0
# 95            1    0
# 97            1    0
# 98            1    0
# 102           1    0
# 106           5    0
# 112          25    0
# 113          17    0
# 114          45    0
# 115          91    0
# 116           3    0
# 117          11    0
# 120          11    0
# ...         ...  ...
# 2009          3    0
# 2011         23    0
# 2012          5    0
# 2018          1    0
# 2019          1    0
# 2023          1    0
# 2025          1    0
# 2029          2    0
# 2034          1    0
# 2038          2    0
# 2039          1    0
# 2043          6    0
# 2044         14    0
# 2045          5    0
# 2047         23    0
# 2048          4    0
# 2049          1    0
# 2050          1    0
# 2051          2    0
# 2053          4    0
# 2062          5    0
# 2064          2    0
# 2065          1    0
# 2067          1    0
# 2073         16    0
# 2074         10    0
# 2076          2    0
# 2079          1    0
# 2080         14    0
# 2083          1    0
#
# [534 rows x 8 columns]

# %% [markdown]
# #### 4.B Verify that `release` contains no null values.

# %%
# A:
print(df.isnull().sum())
# Out:
# Song Clean      0
# ARTIST CLEAN    0
# Release Year    0
# COMBINED        0
# ??First?        0
# ??Year?         0
# PlayCount       0
# F*G             0
# dtype: int64

# %% [markdown]
# ### 5. Ensure that the data types of the columns make sense.
#
# Verifying column data types is a critical part of data munging. If columns have the wrong data type, then there is usually corrupted or incorrect data in some of the observations.
#
# #### 5.A Look at the data types for the columns. Are any incorrect given what the data represents?

# %%
# A:
df.info()

df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2087 entries, 0 to 2086
# Data columns (total 8 columns):
# Song Clean      2087 non-null object
# ARTIST CLEAN    2087 non-null object
# Release Year    2087 non-null float64
# COMBINED        2087 non-null object
# ??First?        2087 non-null int64
# ??Year?         2087 non-null int64
# PlayCount       2087 non-null int64
# F*G             2087 non-null int64
# dtypes: float64(1), int64(4), object(3)
# memory usage: 130.5+ KB
#           Song Clean  ARTIST CLEAN  Release Year  \
# 0    Hold On Loosely   .38 Special        1981.0
# 1  Art For Arts Sake          10cc        1975.0
# 2         Kryptonite  3 Doors Down        2000.0
# 3              Loser  3 Doors Down        2000.0
# 4      When I'm Gone  3 Doors Down        2002.0
#
#                          COMBINED  ??First?  ??Year?  PlayCount  F*G
# 0  Hold On Loosely by .38 Special         1        1         85   85
# 1       Art For Arts Sake by 10cc         1        1          1    1
# 2      Kryptonite by 3 Doors Down         1        1         13   13
# 3           Loser by 3 Doors Down         1        1          1    1
# 4   When I'm Gone by 3 Doors Down         1        1          6    6

# %% [markdown]
# ### 6. Investigate and clean up the `release` column.
#
# The `release` column is a string data type when it should be an integer.
#
# #### 6.A Figure out what value(s) are causing the `release` column to be encoded as a string instead of an integer.

# %%
# A:
df['Release Year'].unique()  
#df.release.unique() #It's not working does space effect so I can't solve it
# Out:
# array([1981., 1975., 2000., 2002., 1992., 1985.,    0., 1980., 1993.,
#        1984., 1977., 1979., 1990., 1986., 1974., 2014., 1987., 1976.,
#        1973., 2001., 1989., 1997., 1995., 1971., 1972., 1994., 1970.,
#        1966., 1965., 1982., 1983., 1955., 1978., 1969., 1999., 1968.,
#        1988., 1962., 2007., 1967., 1958., 1071., 1996., 1991., 2005.,
#        2011., 2004., 2012., 2003., 1998., 2008., 1964., 2013., 2006.,
#        1961., 1963.])

# %% [markdown]
# #### 6.B Look at the rows in which there is incorrect data in the `release` column.

# %%
# A:
relase_mask = df['Release Year'] == "SONGFACTS.COM"
df[relase_mask]
# Out:
# Empty DataFrame
# Columns: [Song Clean, ARTIST CLEAN, Release Year, COMBINED, ??First?, ??Year?, PlayCount, F*G]
# Index: []

# %% [markdown]
# #### 6.C. Clean up the data. Normally we may replace the offending data with null np.nan values, however we previously converted all of the nan values in the release column to zeros so we might as well continue with the same practice. Replacing with 0 (or nan) will allow us to convert the column to numeric.

# %%
# A:
df.info()
df.loc[relase_mask,'Release Year'] = np.nan
df['Release Year'] = df['Release Year'].map(lambda x: float(x))
#df

#df.loc[nullReleasValue, 'Release Year'] = 0

#df.head(15)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2087 entries, 0 to 2086
# Data columns (total 8 columns):
# Song Clean      2087 non-null object
# ARTIST CLEAN    2087 non-null object
# Release Year    2087 non-null float64
# COMBINED        2087 non-null object
# ??First?        2087 non-null int64
# ??Year?         2087 non-null int64
# PlayCount       2087 non-null int64
# F*G             2087 non-null int64
# dtypes: float64(1), int64(4), object(3)
# memory usage: 130.5+ KB

# %%
################
ads = df['Release Year'] == 0  # hwo remove all zeros or change it with what
df[ads]

#df.release.unique() #It's not working does space effect so I can't solve it
# Out:
#                           Song Clean              ARTIST CLEAN  Release Year  \
# 7              Baby, Please Don't Go                     AC/DC           0.0
# 10            CAN'T STOP ROCK'N'ROLL                     AC/DC           0.0
# 12                  Girls Got Rhythm                     AC/DC           0.0
# 16                         Live Wire                     AC/DC           0.0
# 17                        Moneytalks                     AC/DC           0.0
# 19                   Shoot To Thrill                     AC/DC           0.0
# 21                          Sin City                     AC/DC           0.0
# 85            3    0
# 87            2    0
# 94            2    0
# 95            1    0
# 97            1    0
# 98            1    0
# 102           1    0
# 106           5    0
# 112          25    0
# 113          17    0
# 114          45    0
# 115          91    0
# 116           3    0
# 117          11    0
# 120          11    0
# ...         ...  ...
# 2009          3    0
# 2011         23    0
# 2012          5    0
# 2018          1    0
# 2019          1    0
# 2023          1    0
# 2025          1    0
# 2029          2    0
# 2034          1    0
# 2038          2    0
# 2039          1    0
# 2043          6    0
# 2044         14    0
# 2045          5    0
# 2047         23    0
# 2048          4    0
# 2049          1    0
# 2050          1    0
# 2051          2    0
# 2053          4    0
# 2062          5    0
# 2064          2    0
# 2065          1    0
# 2067          1    0
# 2073         16    0
# 2074         10    0
# 2076          2    0
# 2079          1    0
# 2080         14    0
# 2083          1    0
#
# [533 rows x 8 columns]

# %% [markdown]
# ### 7. Get summary statistics for the `release` column using the `.describe()` function.
#
# Now that the `release` column is finally a numeric data type, we can apply the `.describe()` function.
#
# #### 7.A Print out the summary stats for the `release` column. What is the earliest and latest release date?

# %%
# A:
#df.info()
df['Release Year'].describe()
# Out:
# count    2086.000000
# mean     1472.519655
# std       863.132348
# min         0.000000
# 25%         0.000000
# 50%      1973.000000
# 75%      1981.000000
# max      2014.000000
# Name: Release Year, dtype: float64

# %% [markdown]
# #### 7.B Based on the summary statistics, is there anything else wrong with the `release` column?

# %%
# A:
df['Release Year'].unique()
#there many release data are 0 (25%) and one is 1071
df[df ['Release Year'] == 0]
df[df ['Release Year'] == 1071]
# Out:
#     Song Clean ARTIST CLEAN  Release Year             COMBINED  ??First?  \
# 501      Levon   Elton John        1071.0  Levon by Elton John         1
#
#      ??Year?  PlayCount  F*G
# 501        1          8    8

# %% [markdown]
# _Looking at the DataFrame that contains the year 1071, we can see that the year was probably corrupted and should be replaced with something else if possible._

# %% [markdown]
# ### 8. Make changes and investigate using custom functions with `.apply()`.
#
# Let's say we want to traverse every single row in our data set and apply a function to that row.
#
# #### 8.A Write a function that will take a row of a DataFrame and print out the song, artist, and whether or not the release date is < 1970.

# %%
# reload our data to refresh status

columnName = ['Song','Artist','Release','song_artist','first','year','playcount','fg']
df= pd.read_csv(rockfile, names = columnName, skiprows = 1)
df.head()
# Out:
#                 Song        Artist Release                     song_artist  \
# 0    Hold On Loosely   .38 Special    1981  Hold On Loosely by .38 Special
# 1  Art For Arts Sake          10cc    1975       Art For Arts Sake by 10cc
# 2         Kryptonite  3 Doors Down    2000      Kryptonite by 3 Doors Down
# 3              Loser  3 Doors Down    2000           Loser by 3 Doors Down
# 4      When I'm Gone  3 Doors Down    2002   When I'm Gone by 3 Doors Down
#
#    first  year  playcount  fg
# 0      1     1         85  85
# 1      1     1          1   1
# 2      1     1         13  13
# 3      1     1          1   1
# 4      1     1          6   6

# %%
# A:


def release (row):
    print ('_______________________________')
    print (row['Song'], row['Artist'],row['Release'],'< 1970?', int (row['Release']) < 1970)

# %% [markdown]
# #### 8.B Using the `.apply()` function, apply the function you wrote to the first four rows of the DataFrame.
#
# You will need to tell the `apply` function to operate row by row. Setting the keyword argument as `axis=1` indicates that the function should be applied to each row individually.

# %%
# A:
df.head().apply(release, axis=1)
# Out:
# _______________________________
# Hold On Loosely .38 Special 1981 < 1970? False
# _______________________________
# Art For Arts Sake 10cc 1975 < 1970? False
# _______________________________
# Kryptonite 3 Doors Down 2000 < 1970? False
# _______________________________
# Loser 3 Doors Down 2000 < 1970? False
# _______________________________
# When I'm Gone 3 Doors Down 2002 < 1970? False
# 0    None
# 1    None
# 2    None
# 3    None
# 4    None
# dtype: object

# %% [markdown]
# You'll notice that there will be a final output Series of `None` values. The `.apply()` function, if a return value is not specified, will return a Series of `None` values (similar to how the default return for Python functions is `None` when a return statement is not specified).

# %% [markdown]
# ### 9. Write a function that converts cells in a DataFrame to float and otherwise replaces them with `np.nan`.
#
# If applied to our data, it would keep only the numeric information and otherwise input null values.
#
# Recall that the try-except syntax in Python is a great way to try something and take another action if the initial step fails:
#
# ```python
# try:
#     Perform some action.
# except:
#    Perform some other action if the first failed with an error.
# ```
#
# #### 9.A Write the function that takes a column and converts all of its values to float if possible and `np.nan` otherwise. The return value should be the converted Series.

# %%
# A:
df.info()

def value_converter(value):
    try:
        return float (value)
    except :
        return np.nan
    
def column_converter_to_float (column):
    column = column.map(value_converter)
    return column
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2087 entries, 0 to 2086
# Data columns (total 8 columns):
# Song           2087 non-null object
# Artist         2087 non-null object
# Release        1554 non-null object
# song_artist    2087 non-null object
# first          2087 non-null int64
# year           2087 non-null int64
# playcount      2087 non-null int64
# fg             2087 non-null int64
# dtypes: int64(4), object(4)
# memory usage: 130.5+ KB

# %% [markdown]
# #### 9.B Try your function out on the rock song data and ensure the output is what you expected.

# %%
# A:
df2 = df.apply(column_converter_to_float)
df2.head()
# Out:
#    Song  Artist  Release  song_artist  first  year  playcount    fg
# 0   NaN     NaN   1981.0          NaN    1.0   1.0       85.0  85.0
# 1   NaN     NaN   1975.0          NaN    1.0   1.0        1.0   1.0
# 2   NaN     NaN   2000.0          NaN    1.0   1.0       13.0  13.0
# 3   NaN     NaN   2000.0          NaN    1.0   1.0        1.0   1.0
# 4   NaN     NaN   2002.0          NaN    1.0   1.0        6.0   6.0

# %% [markdown]
# #### 9.C Describe the new float-only DataFrame.

# %%
# A: 
df2.describe().T
# Out:
#               count         mean          std     min     25%     50%     75%  \
# Song            2.0  1012.000000  1367.544515    45.0   528.5  1012.0  1495.5
# Artist          0.0          NaN          NaN     NaN     NaN     NaN     NaN
# Release      1553.0  1977.898261    24.875307  1071.0  1971.0  1977.0  1984.0
# song_artist     0.0          NaN          NaN     NaN     NaN     NaN     NaN
# first        2087.0     1.000000     0.000000     1.0     1.0     1.0     1.0
# year         2087.0     0.744609     0.436185     0.0     0.0     1.0     1.0
# playcount    2087.0    16.676090    25.021707     0.0     1.0     4.0    21.0
# fg           2087.0    14.896981    25.049489     0.0     0.0     3.0    17.5
#
#                 max
# Song         1979.0
# Artist          NaN
# Release      2014.0
# song_artist     NaN
# first           1.0
# year            1.0
# playcount     142.0
# fg            142.0
